# %%
#Bai1
n = int(input("nhap so nguyen n:"))
m = n * 2
print (f"So gap doi la:",m)

# %%
#Bai2
a = float(input("chieu dai la:"))
b = float(input("chieu rong la:"))
s = a * b 
m = s - ((b / 2)**2 * 3.14)
print(f"dien tich trong cay xanh la:",m)

# %%
#Bai3
a = input("Nhap vao mot ky tu:")
if a.isupper():
    print("Chu thuong tuong ung la:",a.lower())
elif a.islower():
    print("Chu hoa tuong ung la:",a.upper())
else:
    print("Ban da khong nhap sai ky tu!",a)

# %%
#Bai4
c = input("nhap vao mot ky tu:")
if c.isalpha():
    print(c,"la ki tu alphabet")
else:
    print(c,"khong phai la ki tu alphabet")

# %%
#Bai5
a = input("nhap vao mot chu cai in hoa:")
if a == 'A':
    print(f"Day la truong hop dac biet: A la chu dau tien va khong co chu thuong lien truoc")
elif 'B' <= a <= 'Z':
    chuthuong = a.lower()
    ma_ascii = ord(chuthuong)
    ma_ascii_truoc = ma_ascii - 1
    ky_tu_truoc = chr(ma_ascii_truoc)
    print(ky_tu_truoc)
else:
    print("Dau vao '{a}' khong hop le!!!. Vui long nhap mot chu cai hoa tu A -> Z" )

# %%
#Bai6
import math
a, b, c = map(float,input().split())
if (a > 0 and b > 0 and c > 0) and (a + b > c) and (a + c > b) and (b + c > a):
    d = ( a + b + c )/2
    s = (d * (d -a) * (d - b) * (d - c))
    print("dien tich tam giac la:",s)
else:
    print("khong phai 3 canh cua tam giac.")
# Out:
# dien tich tam giac la: 720.0

# %%
#Bai7
chuoi = input("Nhap vao mot chuoi")
if len(chuoi) < 20:
    print ("Chuoi khong du dieu kien! Phai nhap it nhat 20 ky tu.")
else:
    stt5 = chuoi[4]
    stt9 = chuoi[8]
    print ("so thu tu 5 la:",stt5)
    print ("so thu tu 9 la:",stt9)
# Out:
# so thu tu 5 la: 5
# so thu tu 9 la: 9

# %%
#Bai8
tenchuho = input("Nhap vao ten chu ho")
print ("Ho va ten:",tenchuho)
csothangtrc = int(input("Nhap chi so thang truoc"))
csothangsau = int(input("Nhap chi so thang sau"))
d = csothangsau - csothangtrc
if 0 <= d <= 50:
    stien = d * 1984
    ttien = stien + stien * 0.08
    print ("Tien phai tra la:",int(ttien))
elif 51 <= d <= 100:
    stien = d * 2050
    ttien = stien + stien * 0.08
    print ("Tien phai tra la:",int(ttien))
elif 101 <= d <= 200:
    stien = d * 2380
    ttien = stien + stien * 0.08
    print ("Tien phai tra la:",int(ttien))
elif 201 <= d <= 300:
    stien = d * 2998
    ttien = stien + stien * 0.08
    print ("Tien phai tra la:",int(ttien))
elif 301 <= d <= 400:
    stien = d * 3350
    ttien = stien + stien * 0.08
    print ("Tien phai tra la:",int(ttien))
elif 401 <= d:
    stien = d * 3460
    ttien = stien + stien * 0.08
    print ("Tien phai tra la:",int(ttien))
else:
    print("Nhap sai cu phap! Yeu cau ban nhap chinh xac so lieu!")
# Out:
# Ho va ten: Pham Xuan Toai
# Tien phai tra la: 107136
