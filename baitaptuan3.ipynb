# %%
#W3A4
m = int(input("Nhap vao mot so m:"))
n = int(input("Nhap vao mot so n"))
l = m // n
print(f"So lam tron xuong la:{l}")
# Out:
# So lam tron xuong la:3

# %%
#W3A5
m = int(input("Nhap vao mot so m:"))
n = int(input("Nhap vao mot so n"))
g = m / n
l = m // n
k = g - l
if k > 0:
    print(f"So lam tron len la:{l + 1}")
else:
    print(l)
# Out:
# So lam tron len la:4

# %%
#W3A6
a = int(input("Nhap vao mot so nguyen duong:"))
if a > 0 and a % 2 == 0:
    print("Even")
else:
    print("No")
# Out:
# Even

# %%
#W3A7
a = int(input("Nhap vao so nguyen thu nhat:"))
b = int(input("Nhap vao so nguyen thu 2:"))
if a * b > 0 and a < 0 and b < 0:
    print("Yes")
else:
    print("No")
# Out:
# No

# %%
#W3A8
a = input()
b = input()
if len(a) > len(b):
    print("True")
else:
    print("False")
# Out:
# True

# %%
#W3A9
a , b , c = map(float,input().split())
if (a > 0 and b > 0 and c > 0) and (a + b > c) and (a + c >b) and (b + c > a):
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %%
#W3A10
a, b, c, d = map(int,input("Nhap vao 4 so:").split())
sln = a
if b > sln:
    sln = b
if c > sln:
    sln = c
if d > sln:
    sln = d
print("So lon nhat la:",sln)
# Out:
# So lon nhat la: 4

# %%
#W3A10
a , b , c , d = map(int,input("Nhap vao 4 so:").split())
print ("So lon nhat la:",max(a , b , c , d))
# Out:
# So lon nhat la: 4

# %%
#W3A11
a , b , c = map(int,input().split())
if (a > 0 and b > 0 and c > 0) and (a + b > c) and (a + c > b) and (b + c > a):
    if a == b and b == c:
        print("Tam giac deu")
    elif (a == b) or (b == c) or (a == c):
        print("Tam giac can")
    elif (a*a == b*b + c*c) or (b*b == a*a + c*c) or (c*c == a*a + c*c): 
        print("Tam giac vuong")
    else:
        print("Tam giac thuong")
else:
    print("Khong phai la tam giac")
# Out:
# Tam giac can

# %%
#W3A12
a = int(input("Nhap vao so nam:"))
if a % 4 == 0 and a % 100 != 0 or a % 400 == 0:
    print("Yes")
else:
    print("No")
# Out:
# No

# %%
#W3A13
a = float(input("Nhap a:"))
b = float(input("Nhap b:"))
if a == 0:
    if b == 0:
        print("Vo so nghiem")
    else:
        print("Vo nghiem")
else:
    x = - b / a
    print("nghiem cua pt la:",x)
# Out:
# nghiem cua pt la: 2.0

# %%
#WA15
a = float(input("Nhap vao diem trung binh"))
if 8.0 <= a <=100:
    print("Gioi")
elif 6.5 <= a < 8.0:
    print("Kha")
else:
    print("Trung binh")
# Out:
# Gioi
