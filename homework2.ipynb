# %%
#bai1
a = float(input("Chieu dai hcn la:"))
b = float(input("Chieu rong hinh chu nhat la:"))
if a > b and a != 0 and b != 0:
    print(f"Dien tich hinh chu nhat la: {a * b}")
    print(f"Chu vi hinh chu nhat la: {(a + b) * 2}")
else:
    print("Khong phai la hinh chu nhat!!!")
# Out:
# Dien tich hinh chu nhat la: 48.0
# Chu vi hinh chu nhat la: 28.0

# %%
def sum_even(a): 
  s = 0
  for i in range(len(a)):
    if i % 2 == 0:
      s += a[i]
  return s


numbers = list(map(int, input().strip().split()))
print (sum_even(numbers))
# Out:
# 25

# %%
#bai2
n = float(input("Nhap vao chieu rong cua hinh tron:"))
if n != 0 and n > 0:
    print(f"Dien tich hinh tron la:{ n * n * 3.14 }")
    print(f"Chu vi hinh tron la: {2 * 3.14 * n}")
else:
    print("Ban da nhap sai gia tri!!!")
# Out:
# Dien tich hinh tron la:78.5
# Chu vi hinh tron la: 31.400000000000002

# %%
#Bai3
a , b , c = map(int,input().split())
if (a > 0 and b > 0 and c > 0) and (a + b > c) and (a + c > b) and (b + c > a):
    if a == b and b == c:
        print("Tam giac deu")
    elif (a == b) or (b == c) or (a == c):
        print("Tam giac can")
    elif (a*a == b*b + c*c) or (b*b == a*a + c*c) or (c*c == a*a + c*c): 
        print("Tam giac vuong")
    else:
        print("Tam giac thuong")
else:
    print("Khong phai la tam giac")
d = a + b + c
p = (a + b + c)/2
s = (p*(p-a)*(p-b)*(p-c))
print("DIen tich tam giac la:",s)
print("Chu vi tam giac la:",d)
# Out:
# Tam giac thuong
# DIen tich tam giac la: 36.0
# Chu vi tam giac la: 12

# %%
#bai4
a = float(input("Nhap vao gia tri a:"))
b = float(input("Nhap vao gia tri b:"))
if a == 0:
    if b == 0:
        print("PT vo so nghiem")
    else:
        print("PT vo nghiem")
else:
    x = - b / a
    print("Nghiem cua PT la:",x)
# Out:
# Nghiem cua PT la: 2.0

# %%
#bai5
a , b , c = map(float,input("Nhap vao cac gia tri cua PT bac 2:").split())
denta = b*b - 4 * a * c
if a == b == c == 0:
    print("PT co vo so nghiem.")
elif a == 0:
    x = - c / b
    print("Nghiem cua PT la:",x)
else:
    x1 = (- b + denta*0.5)/2
    x2 = (- b - denta*0.5)/2
    print("Nghiem thu nhat cua pt la:",x1)
    print("Nghiem thu hai cua pt la:",x2)
# Out:
# Nghiem thu nhat cua pt la: -7.25
# Nghiem thu hai cua pt la: 4.25

# %%
#bai6
a, b, c, d = map(int,input("Nhap vao cac so:").split())
sln = a
if b > sln:
    sln = b
if c > sln:
    sln = c
if d > sln:
    sln = d
    print("So lon nhat la:",sln)
else:
    print("So lon nhat la:",sln)
# Out:
# So lon nhat la: 20

# %%
#bai6
a, b, c, d = map(int,input("Nhap vao cac so:").split())
print("Gia tri lon nhat la:",max(a,b,c,d))
# Out:
# Gia tri lon nhat la: 20

# %%
#bai7
a,b,c,d = map(int,input("Nhap vao 4 so:").split())
snn = a
if snn > b:
    snn = b
if snn > c:
    snn = c
if snn > d:
    snn = d
    print("Gia tri nho nhat la:",snn)
else:
    print("Gia tri nho nhat la:",snn)
# Out:
# Gia tri nho nhat la: 1

# %%
#bai7
a, b, c, d = map(int,input("Nhap vao cac so:").split())
print("Gia tri nho nhat la:",min(a,b,c,d))
# Out:
# Gia tri nho nhat la: 1

# %%
#bai8
a,b,m,c,d,n = map(float,input("Nhap vao cac gia tri cua hpt:").split())
det = a * d - b * c
det1 = m * d - b * n
det2 = b * n - m * d
if det != 0:
    x = det1 / det
    y = det2 / det
    print("Hpt co nghiem duy nhat:(x, y) =",(x,y))
else:
    if det1 != 0 or det2 != 0:
        print("Hpt vo nghiem.")
    else:
        print("Hpt co vo so nghiem.")
# Out:
# Hpt co nghiem duy nhat:(x, y) = (-1.0, 1.0)

# %%
#bai9
t = int(input("Nhap vao thoi gian mot cong viec:"))
p = t / 60
h = t / 3600
print("So gio la:",h)
print("So phut la:",p)
print("So giay la:",t)
# Out:
# So gio la: 0.05
# So phut la: 3.0
# So giay la: 180

# %%
#bai10
a,b = map(float,input("Nhap vao tam cua duong tron:").split())
r = float(input("Nhap vao ban kinh cua duong tron:"))
x,y = map(float,input("Nhap vao mot diem bat ky:").split())
d = ((x - a) ** 2 + (y - b) ** 2) ** 0.5
if d <= r:
    print("Diem do thuoc duong tron.")
else:
    print("Diem do khong thuoc duong tron.")
# Out:
# Diem do thuoc duong tron.

# %%
#bai11
x = float(input("Nhap vao so thuc x:"))
y = float(input("Nhap vao so mu y:"))
print("Gia tri ket qua la:", x ** y)
# Out:
# Gia tri ket qua la: 9.0
