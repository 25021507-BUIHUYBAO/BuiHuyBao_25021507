# %%
#W2A1
print ("Hello World!")
# Out:
# Hello World!

# %%
#W2A2
ten = input("Ten cua ban:")
print(f"Chao ban {ten}! rat vui khi duoc gap ban!")
# Out:
# Chao ban Bao! rat vui khi duoc gap ban!

# %%
#W2A3
a = int (input("nhap so:"))
b = int (input("nhap so:"))
print (f"tong la:{a + b}")
print (f"hieu la:{a - b}")
print (f"tich la:{a * b}")
print (f"phan nguyen la:{a//b}")
print (f"phan du la:{a % b}")
print (f"ket qua phep chia thuc la:{a / b:.2f}")
# Out:
# tong la:13
# hieu la:7
# tich la:30
# phan nguyen la:3
# phan du la:1
# ket qua phep chia thuc la:3.33

# %%
#W2A4
scores = list(map(float, input().split()))
a1 = scores[0]
b1 = scores[1]
c1 = scores[2]
a2 = scores[3]
b2 = scores[4]
a3 = scores[5]
tb = ((a1 + b1 + c1) + (a2 + b2) * 2 + a3 *3) / 10
print (f"{tb:.1f}")
# Out:
# 4.2

# %%
#W2A5
a, b = map(int, input().split())
kq = a**b
print(f"ket qua la:",kq)
# Out:
# ket qua la: 25

# %%
#W2A6
ky_tu_thuong = input()
ma_unicode = ord(ky_tu_thuong)
print(f"ma unicode la:",ma_unicode)
ky_tu_hoa = ky_tu_thuong.upper()
print(f"ky tu in hoa la:",ky_tu_hoa)
# Out:
# ma unicode la: 97
# ky tu in hoa la: A

# %%
#W2A7
A = ((13**2)*3)+5
B = 13**2*3 + 5
print (f"ket qua cua bieu thuc A la:",A)
print (f"ket qua cua bieu thuc B la:",B)
# Out:
# ket qua cua bieu thuc A la: 512
# ket qua cua bieu thuc B la: 512

# %%
#W2A8
nhiet_do_celius = float(input())
F = 9/5 * nhiet_do_celius + 32 
print(f"nhiet do fahrenheit la:",F)

# %%
#W2A9
gia_dh = float(input())
tongtien = gia_dh * 1.4 + 10
print (f"tong so tien can tra cho chiec dong ho la:",tongtien)
# Out:
# tong so tien can tra cho chiec dong ho la: 150.0

# %%
#W2A10
ten1, ten2, ten3 = input().split()
print(f"Hi {ten3}, {ten2}, and {ten1}.")
# Out:
# Hi Huy, Bao, and Dung.

# %%
#W2A11
h = int(input("nhap so gio:"))
m = int(input("nhap so phut:"))
sogiosophut = (h * 3600) + (m * 60)
print(f"So giay la:",sogiosophut)
# Out:
# So giay la: 9900

# %%
#w2A12
n = int(input("do dai canh rubik:"))
mdan = 6 * n * n
print(f"So mieng dan la:",mdan)
# Out:
# So mieng dan la: 6

# %%
#W2A13
a = int(input())
b = int(input())
sodonvi = a * b % 10
print(f"So hang don vi la:",sodonvi)
# Out:
# So hang don vi la: 5

# %%
#W2A14
a , b = map(int,input("Nhap hai so a va b:").split())
a = a + b
b = a - b
a = a - b
print (f"gia tri hoan doi:",a , b)
# Out:
# gia tri hoan doi: 12 16

# %%
#W2A15
n = int(input())
so_sao = 6 * n * (n - 1) + 1
print (f"so sao la:",so_sao)
# Out:
# so sao la: 37

# %%
#W2A16
print("Spring\nSummer\nAutumn\nWinter")
# Out:
# Spring
# Summer
# Autumn
# Winter

# %%
#W2A17
print("*\n***\n*****")
# Out:
# *
# ***
# *****

# %%
#W2A18
print("### # #  ### ###\n #  #  #  #  #\n #  #   # #  #\n #  #  #  #  #\n #  # #   #  #")
# Out:
# ### # #  ### ###
#  #  #  #  #  #
#  #  #   # #  #
#  #  #  #  #  #
#  #  # #   #  #

# %%
#W2A19
print("Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday")
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
#W2A20
print("January\nFebruary\nMarch\nApril\nMay\nJune\nJuly\nAugust\nSeptember\nOctober\nNovember\nDecember")
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %%
#W2A21
for i in range (10):
    print("Hello, world")
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
